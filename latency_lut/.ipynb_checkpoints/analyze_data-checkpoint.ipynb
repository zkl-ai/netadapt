# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
f = open("lut_alexnet.pkl","rb")
lookup_table = pickle.load(f)

# %%
def deal_outlier(df:pd.DataFrame):
    for col in df.columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1-1.5*IQR
        upper = Q3+1.5*IQR
        median = df[col].median()
        df[col][lower > df[col]] = median
        df[col][df[col] > upper] = median
    return df

# %%
count = 0
total = 0
layer_names = list(lookup_table.keys())
KEY_LATENCY = "latency"
layer_lookup_table = {}
print(lookup_table.keys())
for layer_name in layer_names:
    table = pd.DataFrame(lookup_table[layer_name][KEY_LATENCY])
    cs = table.columns
    ncs = []
    for c in cs:
        ncs.append("%d_%d"%(c[0],c[1]))
    table.columns = ncs
    layer_lookup_table[layer_name] = table
# Out:
# odict_keys(['features.0', 'features.3', 'features.6', 'features.8', 'features.10', 'classifier.1', 'classifier.4', 'classifier.6'])

# %%
for l in layer_names:
    print(l, len(layer_lookup_table[l].columns))
# Out:
# features.0 8
# features.3 192
# features.6 1152
# features.8 1536
# features.10 1024
# classifier.1 9216
# classifier.4 4096
# classifier.6 64

# %%
table = pd.DataFrame(layer_lookup_table[layer_names[0]])
table.plot(legend=None)
display(table.describe())
# Out:
#               3_64         3_56         3_48         3_40         3_32  \
# count     10.00000    10.000000    10.000000    10.000000    10.000000
# mean   19912.80000  -461.200000   201.200000   207.600000  -859.600000
# std    41777.78871   948.928846   690.967888   891.194355  1200.091034
# min    -1132.00000 -1688.000000  -736.000000 -1016.000000 -2992.000000
# 25%     -495.00000 -1357.000000  -187.000000  -331.000000 -1244.000000
# 50%      398.00000  -352.000000   102.000000   -36.000000  -624.000000
# 75%     1548.00000   269.000000   676.000000   742.000000    31.000000
# max    99348.00000   876.000000  1344.000000  1904.000000   476.000000
#
#               3_24         3_16          3_8
# count    10.000000    10.000000    10.000000
# mean    278.000000    92.800000   -84.400000
# std     849.389323  1113.787213  1068.123089
# min   -1020.000000 -2104.000000 -1800.000000
# 25%    -131.000000  -188.000000  -735.000000
# 50%     430.000000   134.000000    26.000000
# 75%     794.000000   570.000000   757.000000
# max    1632.000000  1576.000000  1420.000000

# %%
dealed_table = deal_outlier(table.copy(deep=True))
dealed_table.plot(legend=None)
display(dealed_table.describe())
# Out:
#             3_64         3_56         3_48         3_40         3_32  \
# count    10.0000    10.000000    10.000000    10.000000    10.000000
# mean    160.0000  -461.200000   201.200000   207.600000  -859.600000
# std     908.9574   948.928846   690.967888   891.194355  1200.091034
# min   -1132.0000 -1688.000000  -736.000000 -1016.000000 -2992.000000
# 25%    -495.0000 -1357.000000  -187.000000  -331.000000 -1244.000000
# 50%     331.0000  -352.000000   102.000000   -36.000000  -624.000000
# 75%     498.5000   269.000000   676.000000   742.000000    31.000000
# max    1680.0000   876.000000  1344.000000  1904.000000   476.000000
#
#               3_24         3_16          3_8
# count    10.000000    10.000000    10.000000
# mean    278.000000   316.600000   -84.400000
# std     849.389323   805.508838  1068.123089
# min   -1020.000000 -1164.000000 -1800.000000
# 25%    -131.000000   113.000000  -735.000000
# 50%     430.000000   143.000000    26.000000
# 75%     794.000000   570.000000   757.000000
# max    1632.000000  1576.000000  1420.000000

# %%
for l in layer_names:
    print(len(table.columns))
    table = pd.DataFrame(layer_lookup_table[l])
    table.plot(legend=None)
    new_table = deal_outlier(table.copy(deep=True))
    new_table.plot(legend=None)
# Out:
# 8
# 8
# 192
# 1152
# 1536
# 1024
# 9216
# 4096
