# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
f = open("./mem_alexnet_mean.pkl","rb")
lookup_table = pickle.load(f)

# %%
layer_names = list(lookup_table.keys())
KEY_LATENCY = "latency"

# %%
for l in layer_names:
    table = lookup_table[l][KEY_LATENCY]
    table = pd.DataFrame(table.values())
    table.plot()
